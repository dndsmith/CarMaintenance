# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Mazda3MPG.csv")
df = df.iloc[:,:6]
df
# Out:
#            Date  Miles  Gallons    MPG  Odometer  Projected Odometer
# 0     8/10/2016  345.0    9.974  34.59   74657.0                 0.0
# 1     8/12/2016  453.6   10.854  41.79   75113.0             75110.6
# 2     8/31/2016  304.3    9.934  30.63   75418.0             75417.3
# 3     10/8/2016  353.1    9.095  38.82   75751.0             75771.1
# 4    10/14/2016  434.3   11.139  38.99   76185.0             76185.3
# ..          ...    ...      ...    ...       ...                 ...
# 104  11/28/2019  309.7   10.970  28.23  115869.7            115869.7
# 105   12/7/2019  348.5    9.724  35.84  116218.2            116218.2
# 106   2/17/2020  373.7    9.786  38.19  120341.0            116591.9
# 107   2/27/2020  379.9   11.774  32.27  121122.0            120720.9
# 108   3/15/2020  314.0    9.168  34.25  121794.0            121436.0
#
# [109 rows x 6 columns]

# %%
# plt.plot(df.to_numpy()[:,0], df.to_numpy()[:,3])
plt.plot(df["Date"], df["MPG"])

# %%
import matplotlib.ticker as ticker

tick_spacing = 282

fig, ax = plt.subplots(1,1)
ax.plot(pd.to_datetime(df["Date"]), df["MPG"], label='_nolegend_')
ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

# ADD MAJOR WORK

# 1. Changed Tires
x = ["2017-08-01", "2017-08-01"]
x = pd.to_datetime(x)
y = [20, 44]
ax.plot(x,y)

# 2. Changed Spark Plugs
x = ["2018-06-01", "2018-06-01"]
x = pd.to_datetime(x)
y = [20, 44]
ax.plot(x,y)

ax.set_ylabel("Miles Per Gallon", size="large", weight="semibold", labelpad=15)
ax.set_xlabel("Recorded 2016-08-10 through 2020-03-15", size="large", weight="semibold", labelpad=15)
ax.legend(["Changed Tires", "Changed Spark Plugs"])
ax.set_title("Fuel Efficiency 2012 Mazda2 SkyActiv", size="x-large", weight="semibold", pad=10)
current_fig = plt.gcf()

# %%
# save figure
current_fig.set_size_inches(12,8)
current_fig.savefig("visualization.png", bbox_inches='tight', dpi=100)
